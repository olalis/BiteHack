# %%
from scipy.fft import fft, ifft
import numpy as np
import csv
import matplotlib.pyplot as plt

# %%
from scipy.fft import fft, fftfreq
import numpy as np

y = np.loadtxt("./pulsik.csv")

# Number of sample points
N = len(y)

# sample spacing
T = 1.0 / 100

x = np.linspace(0.0, N*T, N, endpoint=False)
# y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)

yf = fft(y)
xf = fftfreq(N, T)[:N//2]*6

import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.ylim(-1, 3)
plt.xlim([50,200])
plt.show()
# Out:
# /tmp/ipykernel_15846/1115288335.py:4: UserWarning: loadtxt: input contained no data: "./pulsik.csv"
#   y = np.loadtxt("./pulsik.csv")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/ola/Pulpit/BiteHack/fft_pulse.ipynb Komórka 2 in <cell line: 15>()
#      <a href='vscode-notebook-cell:/home/ola/Pulpit/BiteHack/fft_pulse.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a> x = np.linspace(0.0, N*T, N, endpoint=False)
#      <a href='vscode-notebook-cell:/home/ola/Pulpit/BiteHack/fft_pulse.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a> # y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
# ---> <a href='vscode-notebook-cell:/home/ola/Pulpit/BiteHack/fft_pulse.ipynb#W1sZmlsZQ%3D%3D?line=14'>15</a> yf = fft(y)
#      <a href='vscode-notebook-cell:/home/ola/Pulpit/BiteHack/fft_pulse.ipynb#W1sZmlsZQ%3D%3D?line=15'>16</a> xf = fftfreq(N, T)[:N//2]*6
# ...

# %%
from scipy.fft import fft, fftfreq
import numpy as np

y = np.loadtxt("./pulsik1.csv")

# Number of sample points
N = len(y)

# sample spacing
T = 1.0 / 100

x = np.linspace(0.0, N*T, N, endpoint=False)
# y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)

yf = fft(y)
xf = fftfreq(N, T)[:N//2]*6

import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.ylim(-1, 3)
plt.xlim([50,200])
plt.show()

# %%
# print(len(yf))
new_yf = yf[500:2000]
# print(new_yf)
print(new_yf.argmax(axis=0))
print(xf[new_yf.argmax(axis=0) + 500])
# Out:
# 302
# 84.21421071053553

# %%
from scipy.fft import fft, fftfreq
import numpy as np
import csv

y = np.loadtxt("./pulsik1.csv")

# Number of sample points
N = len(y)

# sample spacing
T = 1.0 / 100
x = np.linspace(0.0, N*T, N, endpoint=False)

yf = fft(y)
xf = fftfreq(N, T)[:N//2]*6

new_yf = yf[500:2000]
pulse = xf[new_yf.argmax(axis=0) + 500]

# %%
print(pulse)
# Out:
# 95.16000000000001
